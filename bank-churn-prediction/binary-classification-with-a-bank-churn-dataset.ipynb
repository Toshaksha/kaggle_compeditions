# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/binaryclassificationwithabankchurndatasetumgc/sample_submission.csv
# /kaggle/input/binaryclassificationwithabankchurndatasetumgc/train.csv
# /kaggle/input/binaryclassificationwithabankchurndatasetumgc/test.csv

# %% [markdown]
# # Model Workflow
# - Loaded and explored data
# - Cleaned and dropped irrelevant columns
# - Encoded categorical variables
# - Split features & target
# - Train-test split done with stratification
# - Standardized numerical features
# - Trained Logistic Regression model with balanced weights
# - Evaluated using ROC AUC on test set

# %% [markdown]
# # Step-1
# ### Loading Dataset

# %%
bank_churn_data = pd.read_csv("/kaggle/input/binaryclassificationwithabankchurndatasetumgc/train.csv")

# %% [markdown]
# # Step- 2
# ### Understanding Our Data

# %%
# Printing the first 5 lines of our datset
bank_churn_data.head()
# Out:
#    id  CustomerId  Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0   0  15788494.0      Chu        591.0     Spain    Male  30.0     4.0
# 1   1  15743893.0   Ch'ang        544.0     Spain  Female  47.0     1.0
# 2   2  15738884.0  Mancini        705.0    France    Male  37.0     9.0
# 3   3  15795586.0  Chikelu        670.0    France    Male  40.0    10.0
# 4   4  15586518.0     Tsou        714.0     Spain  Female  46.0     1.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0  112419.92            1.0        0.0             0.0         88890.05
# 1       0.00            1.0        1.0             0.0         80120.19
# 2       0.00            2.0        1.0             1.0         79919.13
# 3       0.00            2.0        1.0             1.0         55835.66
# 4  107879.06            1.0        1.0             0.0        162697.93
#
#    Exited
# 0     0.0
# 1     1.0
# 2     0.0
# 3     0.0
# 4     0.0

# %%
# Checking dimensions of our data (rows,columns)
bank_churn_data.shape
# Out:
# (15000, 14)

# %%
# Understanding Value Count for our "Exited" Column
bank_churn_data["Exited"].value_counts()
# Out:
# Exited
# 0.0    11966
# 1.0     3034
# Name: count, dtype: int64

# %% [markdown]
# **Label Explanation**
# - 0.0 → Customer stayed (did not churn)
# - 1.0 → Customer exited (churned)

# %%
# get statistical summary of data
bank_churn_data.describe()
# Out:
#                  id    CustomerId   CreditScore           Age        Tenure  \
# count  15000.000000  1.500000e+04  15000.000000  15000.000000  15000.000000
# mean    7499.500000  1.571083e+07    657.576267     37.690333      5.015800
# std     4330.271354  1.637345e+06     72.135924      8.125600      2.804724
# min        0.000000  1.567894e+06    431.000000     18.000000      0.000000
# 25%     3749.750000  1.563557e+07    601.000000     32.000000      3.000000
# 50%     7499.500000  1.569054e+07    660.000000     37.000000      5.000000
# 75%    11249.250000  1.575787e+07    708.000000     42.000000      7.000000
# max    14999.000000  1.581198e+08    850.000000     72.000000     10.000000
#
#              Balance  NumOfProducts     HasCrCard  IsActiveMember  \
# count   15000.000000   15000.000000  15000.000000    15000.000000
# mean    42391.092967       1.586000      0.782133        0.497733
# std     59657.264519       0.529864      0.412810        0.500012
# min         0.000000       1.000000      0.000000        0.000000
# 25%         0.000000       1.000000      1.000000        0.000000
# 50%         0.000000       2.000000      1.000000        0.000000
# 75%    108910.382500       2.000000      1.000000        1.000000
# max    187911.550000       4.000000      1.000000        1.000000
#
#        EstimatedSalary        Exited
# count     1.500000e+04  15000.000000
# mean      1.172384e+05      0.202267
# std       4.672902e+04      0.401703
# min       4.477300e+02      0.000000
# 25%       8.246369e+04      0.000000
# 50%       1.224886e+05      0.000000
# 75%       1.558885e+05      0.000000
# max       1.387001e+06      1.000000

# %% [markdown]
# # Step- 3
# ### Clean and Prepare data

# %%
# Check for missing values
bank_churn_data.isnull().sum()
# Out:
# id                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Drop irrelevant columns
bank_churn_data = bank_churn_data.drop(columns = ["id", "CustomerId", "Surname"])

# %%
bank_churn_data.head()
# Out:
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0        591.0     Spain    Male  30.0     4.0  112419.92            1.0
# 1        544.0     Spain  Female  47.0     1.0       0.00            1.0
# 2        705.0    France    Male  37.0     9.0       0.00            2.0
# 3        670.0    France    Male  40.0    10.0       0.00            2.0
# 4        714.0     Spain  Female  46.0     1.0  107879.06            1.0
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0        0.0             0.0         88890.05     0.0
# 1        1.0             0.0         80120.19     1.0
# 2        1.0             1.0         79919.13     0.0
# 3        1.0             1.0         55835.66     0.0
# 4        1.0             0.0        162697.93     0.0

# %% [markdown]
# # Step - 4
# ### Label Encoding
# Label encoding converts categorical labels into numeric form so machine learning models can process them.

# %%
# Understanding Value count for Categorical
#  labels i.e "Geography" and "Gender"

# %%
bank_churn_data["Gender"].value_counts()
# Out:
# Gender
# Male      8515
# Female    6485
# Name: count, dtype: int64

# %%
bank_churn_data["Geography"].value_counts()
# Out:
# Geography
# France     8946
# Spain      3338
# Germany    2716
# Name: count, dtype: int64

# %% [markdown]
# Encoding Categorical Values

# %%
# importing Label Encoder
from sklearn.preprocessing import LabelEncoder

# %%
# Assigning Label Encoder to variable "Label_encode"
label_encode = LabelEncoder()

# %%
# Encoding "Geography" column
label1 = label_encode.fit_transform(bank_churn_data.Geography)

# %%
# Assigning Encoded values to "Geography" Column
bank_churn_data["Geography"] = label1

# %%
bank_churn_data["Geography"].value_counts()
# Out:
# Geography
# 0    8946
# 2    3338
# 1    2716
# Name: count, dtype: int64

# %% [markdown]
# ***Label Explanation:-***
# - 0 ---> France
# - 1 ---> Germany
# - 2 ---> Spain

# %%
# Reapeating same steps for "Gender" column
label2 = label_encode.fit_transform(bank_churn_data.Gender)

# %%
bank_churn_data["Gender"] = label2

# %%
bank_churn_data["Gender"].value_counts()
# Out:
# Gender
# 1    8515
# 0    6485
# Name: count, dtype: int64

# %% [markdown]
# ***Label Explanation:-***
# - 0 ---> Female
# - 1 ---> Male

# %% [markdown]
# # Step - 5
# ### Features and Target Split

# %%
# Features
X = bank_churn_data.drop(columns = "Exited")

# %%
# Target
Y = bank_churn_data["Exited"]

# %% [markdown]
# # Step - 6
# ### Train - Test Split

# %%
# importing dependency
from sklearn.model_selection import train_test_split

# %%
# Splitting data into test and train split
X_train , X_test , Y_train , Y_test = train_test_split(
    X, Y , test_size = 0.2, stratify = Y, random_state = 0
)

# %%
# Printing Dimensions
print(f"Feature Data Dimensions: {X.shape}")
print(f"Training Data Dimensions: {X_train.shape}")
print(f"Test Data Dimensions: {X_test.shape}")
# Out:
# Feature Data Dimensions: (15000, 10)
# Training Data Dimensions: (12000, 10)
# Test Data Dimensions: (3000, 10)

# %% [markdown]
# # Step - 7
# ### Data Standarization

# %%
# importing dependencies
from sklearn.preprocessing import StandardScaler

# Assigning Standard scaler to variable "Scaler"
scaler = StandardScaler()

# %%
# list of columns to be standardized
num_cols = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

# Fit the model on X_train
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])

# Apply the scaling parameters learned from training data to the test data
X_test[num_cols] = scaler.transform(X_test[num_cols])

# %%
# Check if the numerical features are standardized (mean ~ 0, std ~ 1)
print(X_train[num_cols].mean())
print(X_train[num_cols].std())
# Out:
# CreditScore        3.493502e-17
# Age                4.736952e-18
# Tenure             4.559316e-17
# Balance            6.809368e-18
# NumOfProducts     -1.953993e-17
# EstimatedSalary    1.243450e-17
# dtype: float64
# CreditScore        1.000042
# Age                1.000042
# Tenure             1.000042
# Balance            1.000042
# NumOfProducts      1.000042
# EstimatedSalary    1.000042
# dtype: float64

# %% [markdown]
# # Step - 8
# ### Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# Initialize model with balanced class weights
model = LogisticRegression(class_weight='balanced', random_state=0, max_iter=1000)

# Train the model
model.fit(X_train, Y_train)

# Predict probabilities on test set
y_probs = model.predict_proba(X_test)[:,1]  # Probabilities for class 1

# Evaluate ROC AUC score
auc_score = roc_auc_score(Y_test, y_probs)
print(f"ROC AUC Score: {auc_score:.4f}")
# Out:
# ROC AUC Score: 0.8785

# %% [markdown]
# # Step- 9
# ### Loading and Preparing the test data (test.csv)

# %%
# Load test data 
test_data = pd.read_csv("/kaggle/input/binaryclassificationwithabankchurndatasetumgc/test.csv")

# %%
test_data.head()
# Out:
#       id  CustomerId  Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0  15000  15686936.0     Ting        537.0    France  Female  53.0     4.0
# 1  15001  15733032.0       K?        652.0    France  Female  39.0     9.0
# 2  15002  15674928.0    Hsieh        675.0    France    Male  49.0     5.0
# 3  15003  15783030.0  Mancini        753.0   Germany    Male  51.0     5.0
# 4  15004  15752953.0   Walker        627.0   Germany    Male  35.0     4.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.00            2.0        1.0             1.0        119712.78
# 1       0.00            1.0        1.0             0.0         54164.01
# 2       0.00            2.0        0.0             1.0        132973.21
# 3  127864.40            1.0        0.0             1.0        183868.01
# 4  126663.51            2.0        1.0             0.0         79616.37

# %%
# keeping the "id" for submission file
test_ids = test_data["id"]

# %%
# Droping Irrelevant Columns
test_data = test_data.drop(columns = ["id", "CustomerId", "Surname"])

# %% [markdown]
# ### Label Encoding

# %%
label_a = label_encode.fit_transform(test_data.Geography)
test_data["Geography"] = label_a

# %%
label_b = label_encode.fit_transform(test_data.Gender)
test_data["Gender"] = label_b

# %% [markdown]
# ### Data Standardization

# %%
test_data[num_cols] = scaler.transform(test_data[num_cols])

# %% [markdown]
# # Step - 10
# ### Predict Probabilities

# %%
test_probs = model.predict_proba(test_data)[:,1]

# %% [markdown]
# # Step - 11
# ### Prepare submission dataframe

# %%
submission = pd.DataFrame({
    'id': test_ids,
    'Exited': test_probs
})

# %%
# Save submission file
submission.to_csv("submission.csv", index=False)
print("Submission file created!")
# Out:
# Submission file created!
